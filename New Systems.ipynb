# %%
import TTVModel, TTVLightCurve
from dataInteraction import read_data 

import warnings
warnings.filterwarnings('ignore')

# %%
model = read_data(EPIC="211315836", campaign=5)
model.lightcurve.plot()
model.plot_folded()
# Out:
# Calculated parameters: t0 = 2307.4505917778624, period = 1.375778493385369
# Using calculated parameters.

# %%
model = read_data(EPIC="211319617", campaign=5)
model.lightcurve.plot()
model.optimise()
# Out:
# Calculated parameters: t0 = 2310.390596966726, period = 8.867466865430226
# Using calculated parameters.
# Optimising the shape of the orbital model:
# optimizing logp for variables: [b, r, u, t0, mean]
# ...
# 	 mean = 1.0000008170998995
# 	 t0 = -0.0010585934427368418
# 	 u = [0.32520518 0.25913135]
# 	 r = 0.03217894174242027
# 	 b = 0.6446589751745865
# Fitting ttv for transit number 0
# message: Desired error not necessarily achieved due to precision loss.
# logp: 8315.975119785728 -> 24304.97321011203
# 	 ttv 0 = 0.04055054339730176
# Fitting ttv for transit number 1
# 	 ttv 1 = 0.0001791560630158718
# Fitting ttv for transit number 2
# 	 ttv 2 = -0.0002478178460844023
# Fitting ttv for transit number 3
# 	 ttv 3 = -0.0013131599865474281
# Fitting ttv for transit number 4
# 	 ttv 4 = 0.0006801217780292448
# Fitting ttv for transit number 5
# 	 ttv 5 = -0.001713402237566942
# Fitting ttv for transit number 6
# 	 ttv 6 = -0.002337802818634881
# Fitting ttv for transit number 7
# ...

# %%
model = read_data(EPIC="211327855", campaign=5)
model.lightcurve.plot()
model.optimise()
# Out:
# Found parameters: t0 = 2306.7005, p = 1.72397
# Reference parameters: t0 = 2306.6471330422314, period = 1.7235216781356273
# Optimising the shape of the orbital model:
# optimizing logp for variables: [b, r, u, t0, mean]
# message: Desired error not necessarily achieved due to precision loss.
# logp: 2321.921637659923 -> 25909.793140905644
# 	 mean = 1.0000054680945347
# 	 t0 = 0.057490107589733476
# 	 u = [ 1.05316381 -0.25299176]
# 	 r = 0.014335889099775158
# 	 b = 0.7818970101671303
# Fitting ttv for transit number 0
# 	 ttv 0 = 0.06250298091721566
# Fitting ttv for transit number 1
# 	 ttv 1 = 0.045423881049034956
# Fitting ttv for transit number 2
# 	 ttv 2 = 0.059785589212468286
# Fitting ttv for transit number 3
# 	 ttv 3 = 0.05943088618277405
# Fitting ttv for transit number 4
# 	 ttv 4 = 0.05440995096391708
# Fitting ttv for transit number 5
# 	 ttv 5 = 0.05115037674043345
# Fitting ttv for transit number 6
# 	 ttv 6 = 0.054856427897282865
# ...

# %%
model = read_data(EPIC="211331236", campaign=5)
model.lightcurve.plot()
model.optimise()
# Out:
# Found parameters: t0 = 2307.19095, p = 1.291605
# Reference parameters: t0 = 2307.1911221153114, period = 1.290132275755151
# Optimising the shape of the orbital model:
# optimizing logp for variables: [b, r, u, t0, mean]
# message: Optimization terminated successfully.
# logp: 8668.119954421303 -> 20819.943101166882
# 	 mean = 1.0000214063878543
# 	 t0 = 0.03893810021403906
# 	 u = [ 0.58959471 -0.14750219]
# 	 r = 0.0237106534900053
# 	 b = 0.12708926334765122
# Fitting ttv for transit number 0
# 	 ttv 0 = 0.009566715387098327
# Fitting ttv for transit number 1
# 	 ttv 1 = 0.008371167942666477
# Fitting ttv for transit number 2
# 	 ttv 2 = 0.006763150884970525
# Fitting ttv for transit number 3
# 	 ttv 3 = 0.0026534675895481924
# Fitting ttv for transit number 4
# 	 ttv 4 = 0.015880412796780003
# Fitting ttv for transit number 5
# 	 ttv 5 = 0.017198885482164656
# Fitting ttv for transit number 6
# 	 ttv 6 = 0.014269061897813393
# Fitting ttv for transit number 7
# ...
